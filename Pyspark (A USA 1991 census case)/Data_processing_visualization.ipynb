# %%
from pyspark import *
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Data Summary
# https://archive.ics.uci.edu/ml/datasets/Adult
#
# Attribute Information:
#
# Listing of attributes:
#
# >50K, <=50K.
#
# #### Feature 1 =  age: continuous.
# #### Feature 2 = workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# #### Feature 3 = fnlwgt: continuous.
# #### Feature 4 = education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# #### Feature 5 = education-num: continuous.
# #### Feature 6 = marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# #### Feature 7 = occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# #### Feature 8 = relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# #### Feature 9 = race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# #### Feature 10 = sex: Female, Male.
# #### Feature 11 = capital-gain: continuous.
# #### Feature 12 = capital-loss: continuous.
# #### Feature 13 = hours-per-week: continuous.
# #### Feature 14 = native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.

# %%
#Step 1: Read the table from the spark data
census = spark.read.table("adult_csv")
#Step2 : Reading the Table Schema
census.printSchema()
#Step 3: Rading the column names
census_col = census.columns
census.dtypes
#census = census.withColumnRenamed("age", "Age")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- age: integer (nullable = true)
# -- employer_type: string (nullable = true)
# -- numf1: integer (nullable = true)
# -- education: string (nullable = true)
# -- numf2: integer (nullable = true)
# -- marital: string (nullable = true)
# -- occupation: string (nullable = true)
# -- relationship: string (nullable = true)
# -- race: string (nullable = true)
# -- gender: string (nullable = true)
# -- capitalgain: integer (nullable = true)
# -- capitalloss: integer (nullable = true)
# -- hr_per_wk: integer (nullable = true)
# -- region: string (nullable = true)
# -- income: string (nullable = true)
#
# </div>

# %%
census.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: 48842</div>

# %%
# printing limited columns we use select keyword
census.select("employer_type", "marital", "income").show() # Our 2nd transformation (4 >> 3 columns)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------------+------------------+------+
#    employer_type|           marital|income|
# +----------------+------------------+------+
#          Private|     Never-married| &lt;=50K|
#          Private|Married-civ-spouse| &lt;=50K|
#        Local-gov|Married-civ-spouse|  &gt;50K|
#          Private|Married-civ-spouse|  &gt;50K|
#                ?|     Never-married| &lt;=50K|
#          Private|     Never-married| &lt;=50K|
#                ?|     Never-married| &lt;=50K|
# Self-emp-not-inc|Married-civ-spouse|  &gt;50K|
#          Private|     Never-married| &lt;=50K|
#          Private|Married-civ-spouse| &lt;=50K|
#          Private|Married-civ-spouse|  &gt;50K|
#      Federal-gov|Married-civ-spouse| &lt;=50K|
#          Private|     Never-married| &lt;=50K|
#                ?|Married-civ-spouse| &lt;=50K|
#          Private|Married-civ-spouse|  &gt;50K|
#          Private|Married-civ-spouse|  &gt;50K|
#        State-gov|     Never-married| &lt;=50K|
#          Private|Married-civ-spouse| &lt;=50K|
#          Private|           Widowed| &lt;=50K|
#          Private|Married-civ-spouse|  &gt;50K|
# +----------------+------------------+------+
# only showing top 20 rows
#
# </div>

# %%
# check for all missing values in Dataframe
import pyspark.sql.functions as F
#cols = [count(c=='?')  for c in census.columns]
cout = [census[census[c]=="?"].count() for c in census.columns]
print(census.columns)
cout
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;age&#39;, &#39;employer_type&#39;, &#39;numf1&#39;, &#39;education&#39;, &#39;numf2&#39;, &#39;marital&#39;, &#39;occupation&#39;, &#39;relationship&#39;, &#39;race&#39;, &#39;gender&#39;, &#39;capitalgain&#39;, &#39;capitalloss&#39;, &#39;hr_per_wk&#39;, &#39;region&#39;, &#39;income&#39;]
# Out[8]: [0, 2799, 0, 0, 0, 0, 2809, 0, 0, 0, 0, 0, 0, 857, 0]</div>

# %%
step1 = [F.when(~F.col(x).isin("?","NULL", "NA", "NaN"), F.col(x)).alias(x)  for x in census.columns] 
step2 = census.select(*step1).dropna(how='any')
step3 = step2.drop('numf1','numf2')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #KPI 1

# %%
#KPI1
display(step3.select(['age','income']))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>income</th></tr></thead><tbody><tr><td>25</td><td><=50K</td></tr><tr><td>38</td><td><=50K</td></tr><tr><td>28</td><td>>50K</td></tr><tr><td>44</td><td>>50K</td></tr><tr><td>34</td><td><=50K</td></tr><tr><td>63</td><td>>50K</td></tr><tr><td>24</td><td><=50K</td></tr><tr><td>55</td><td><=50K</td></tr><tr><td>65</td><td>>50K</td></tr><tr><td>36</td><td><=50K</td></tr><tr><td>26</td><td><=50K</td></tr><tr><td>48</td><td>>50K</td></tr><tr><td>43</td><td>>50K</td></tr><tr><td>20</td><td><=50K</td></tr><tr><td>43</td><td><=50K</td></tr><tr><td>37</td><td><=50K</td></tr><tr><td>34</td><td>>50K</td></tr><tr><td>34</td><td><=50K</td></tr><tr><td>25</td><td><=50K</td></tr><tr><td>25</td><td><=50K</td></tr><tr><td>45</td><td>>50K</td></tr><tr><td>22</td><td><=50K</td></tr><tr><td>23</td><td><=50K</td></tr><tr><td>54</td><td><=50K</td></tr><tr><td>32</td><td><=50K</td></tr><tr><td>46</td><td>>50K</td></tr><tr><td>56</td><td><=50K</td></tr><tr><td>24</td><td><=50K</td></tr><tr><td>23</td><td><=50K</td></tr><tr><td>26</td><td><=50K</td></tr><tr><td>36</td><td>>50K</td></tr><tr><td>22</td><td><=50K</td></tr><tr><td>17</td><td><=50K</td></tr><tr><td>20</td><td><=50K</td></tr><tr><td>65</td><td>>50K</td></tr><tr><td>44</td><td>>50K</td></tr><tr><td>36</td><td><=50K</td></tr><tr><td>29</td><td><=50K</td></tr><tr><td>20</td><td><=50K</td></tr><tr><td>28</td><td>>50K</td></tr><tr><td>39</td><td><=50K</td></tr><tr><td>54</td><td><=50K</td></tr><tr><td>52</td><td><=50K</td></tr><tr><td>56</td><td><=50K</td></tr><tr><td>18</td><td><=50K</td></tr><tr><td>39</td><td><=50K</td></tr><tr><td>21</td><td><=50K</td></tr><tr><td>22</td><td>>50K</td></tr><tr><td>38</td><td><=50K</td></tr><tr><td>21</td><td><=50K</td></tr><tr><td>63</td><td><=50K</td></tr><tr><td>34</td><td>>50K</td></tr><tr><td>42</td><td>>50K</td></tr><tr><td>33</td><td><=50K</td></tr><tr><td>30</td><td><=50K</td></tr><tr><td>39</td><td><=50K</td></tr><tr><td>26</td><td><=50K</td></tr><tr><td>33</td><td><=50K</td></tr><tr><td>47</td><td><=50K</td></tr><tr><td>41</td><td>>50K</td></tr><tr><td>19</td><td><=50K</td></tr><tr><td>46</td><td><=50K</td></tr><tr><td>43</td><td><=50K</td></tr><tr><td>55</td><td>>50K</td></tr><tr><td>46</td><td><=50K</td></tr><tr><td>30</td><td><=50K</td></tr><tr><td>21</td><td><=50K</td></tr><tr><td>46</td><td><=50K</td></tr><tr><td>41</td><td><=50K</td></tr><tr><td>69</td><td><=50K</td></tr><tr><td>50</td><td><=50K</td></tr><tr><td>20</td><td><=50K</td></tr><tr><td>45</td><td><=50K</td></tr><tr><td>23</td><td><=50K</td></tr><tr><td>24</td><td><=50K</td></tr><tr><td>31</td><td><=50K</td></tr><tr><td>43</td><td><=50K</td></tr><tr><td>20</td><td><=50K</td></tr><tr><td>55</td><td>>50K</td></tr><tr><td>24</td><td><=50K</td></tr><tr><td>59</td><td><=50K</td></tr><tr><td>49</td><td><=50K</td></tr><tr><td>33</td><td>>50K</td></tr><tr><td>59</td><td><=50K</td></tr><tr><td>34</td><td><=50K</td></tr><tr><td>20</td><td><=50K</td></tr><tr><td>25</td><td><=50K</td></tr><tr><td>49</td><td><=50K</td></tr><tr><td>59</td><td>>50K</td></tr><tr><td>20</td><td><=50K</td></tr><tr><td>33</td><td><=50K</td></tr><tr><td>22</td><td><=50K</td></tr><tr><td>58</td><td><=50K</td></tr><tr><td>52</td><td><=50K</td></tr><tr><td>36</td><td><=50K</td></tr><tr><td>41</td><td><=50K</td></tr><tr><td>28</td><td><=50K</td></tr><tr><td>19</td><td><=50K</td></tr><tr><td>18</td><td><=50K</td></tr><tr><td>18</td><td><=50K</td></tr><tr><td>28</td><td><=50K</td></tr><tr><td>29</td><td>>50K</td></tr><tr><td>40</td><td><=50K</td></tr><tr><td>26</td><td><=50K</td></tr><tr><td>46</td><td><=50K</td></tr><tr><td>23</td><td><=50K</td></tr><tr><td>44</td><td><=50K</td></tr><tr><td>43</td><td>>50K</td></tr><tr><td>31</td><td><=50K</td></tr><tr><td>18</td><td><=50K</td></tr><tr><td>19</td><td><=50K</td></tr><tr><td>41</td><td><=50K</td></tr><tr><td>41</td><td><=50K</td></tr><tr><td>69</td><td> ...

# %%
# Step 4.1 Selecting Columns
step3.select('education','income').head(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: [Row(education=&#39;11th&#39;, income=&#39;&lt;=50K&#39;),
#  Row(education=&#39;HS-grad&#39;, income=&#39;&lt;=50K&#39;),
#  Row(education=&#39;Assoc-acdm&#39;, income=&#39;&gt;50K&#39;),
#  Row(education=&#39;Some-college&#39;, income=&#39;&gt;50K&#39;),
#  Row(education=&#39;Some-college&#39;, income=&#39;&lt;=50K&#39;)]</div>

# %%
#df = spark.read.options(header =True, inferSchema = True).csv("mtcars")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Filtering data two ways tp do that second one is slower
step3[(step3.age>30) & (step3.age<35)].show(5)
#step3.filter((step3.age>30) & (step3.age<35)).show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+----------------+------------+------------------+---------------+-------------+-----+------+-----------+-----------+---------+-------------+------+
# age|   employer_type|   education|           marital|     occupation| relationship| race|gender|capitalgain|capitalloss|hr_per_wk|       region|income|
# +---+----------------+------------+------------------+---------------+-------------+-----+------+-----------+-----------+---------+-------------+------+
#  34|         Private|        10th|     Never-married|  Other-service|Not-in-family|White|  Male|          0|          0|       30|United-States| &lt;=50K|
#  34|         Private|   Bachelors|Married-civ-spouse|   Tech-support|      Husband|White|  Male|          0|          0|       47|United-States|  &gt;50K|
#  34|         Private|Some-college|     Never-married|  Other-service|    Own-child|Black|Female|          0|          0|       35|United-States| &lt;=50K|
#  32|Self-emp-not-inc|Some-college|     Never-married| Prof-specialty|Not-in-family|White|  Male|          0|          0|       60|United-States| &lt;=50K|
#  34|       Local-gov|   Bachelors|Married-civ-spouse|Exec-managerial|      Husband|White|  Male|       3103|          0|       50|United-States|  &gt;50K|
# +---+----------------+------------+------------------+---------------+-------------+-----+------+-----------+-----------+---------+-------------+------+
# only showing top 5 rows
#
# </div>

# %%
#Addning the new column
#step3.withColumn('new',step3.capitalgain-step3.capitalloss).show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# categorizing age group
def categorizer(age):
  if age < 30:
    return "young"
  elif age < 45:
    return "middle"
  elif age < 60:
    return "senior"
  elif age < 60:
    return "top senior"
  else: 
    return "retired"
# i have to write udf(user defined functions and below is one way to do so)
# udf(user defined function) the function and its type and then use withcolumn to apply the transformation  
from pyspark.sql.functions import udf
from pyspark.sql.types import *
bucket_udf = udf(categorizer, StringType() )     
step3 = step3.withColumn("age group", bucket_udf("age"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# categorizing hrs/week
def worktimecategorizer(hours):
  if hours <= 25:
    return "Temp"
  elif hours <= 45:
    return "Full time"
  else:
    return "Overtime"
# i have to write udf(user defined functions and below is one way to do so)
from pyspark.sql.functions import udf
from pyspark.sql.types import *
workbucket_udf = udf(worktimecategorizer, StringType())     
step3 = step3.withColumn("workhour", workbucket_udf("hr_per_wk")).drop('hr_per_wk').withColumnRenamed('workhour','hr/wk')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
Asia=['China','Hong','India','Iran','Cambodia','Japan', 'Laos',
        ' Philippines' ,' Vietnam' ,' Taiwan', ' Thailand']
North_America = ['Canada','United-States','Puerto-Rico' ]

Europe = ['England' ,'France', 'Germany' ,'Greece','Holand-Netherlands','Hungary',
            'Ireland','Italy','Poland','Portugal','Scotland','Yugoslavia']

Latin_and_SouthAmerica = ['Columbia','Cuba','Dominican-Republic','Ecuador',
                             'El-Salvador','Guatemala',' Haiti',' Honduras',
                             'Mexico','Nicaragua','Outlying-US(Guam-USVI-etc)','Peru',
                             'Jamaica','Trinadad&Tobago']
Other= ['South']

def regionlist(countries):
  if countries in Asia:
    return "Asia"
  if countries in North_America:
    return "North America"
  if countries in Europe:
    return "Europe"
  if countries in Latin_and_SouthAmerica:
    return "Latin & South America"
  else:
    return "Others"
# udf(user defined function) the function and its type and then use withcolumn to apply the transformation  
region_udf = udf(regionlist,StringType())
step3 = step3.withColumn("Reg",region_udf("region")).drop('region').withColumnRenamed('Reg','region')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def employementtype(job):
  if(job=='Never-worked'or job=='Without-pay'):
    return "Unemployed"
  if(job=='State-gov' or job=='Local-gov'):
    return "Govt"
  if(job=='Self-emp-inc' or job=='Self-emp-not-inc'):
    return "self_emp"
  else:
    return(job)
# udf(user defined function) the function and its type and then use withcolumn to apply the transformation  
etype_udf = udf(employementtype,StringType())
step3 = step3.withColumn("employement", etype_udf("employer_type")).drop('employer_type').withColumnRenamed('employement','employer type')
#employementtype('Never-worked')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def maritalstat(mar):
  #mar= as.character(mar)
  
  if mar in ['Separated','Widowed','Divorced']:
    return "Not-Married"
  elif mar== 'Never-married':
    return "Never-married"
  else: 
    return "Married"
# udf(user defined function) the function and its type and then use withcolumn to apply the transformation
marital_udf = udf(maritalstat,StringType())
step3 = step3.withColumn("status", marital_udf("marital")).drop('marital').withColumnRenamed('status','marital')
#maritalstat('Separated')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
step3.printSchema()
step3.cache()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- age: integer (nullable = true)
# -- education: string (nullable = true)
# -- occupation: string (nullable = true)
# -- relationship: string (nullable = true)
# -- race: string (nullable = true)
# -- gender: string (nullable = true)
# -- capitalgain: integer (nullable = true)
# -- capitalloss: integer (nullable = true)
# -- income: string (nullable = true)
# -- age group: string (nullable = true)
# -- hr/wk: string (nullable = true)
# -- region: string (nullable = true)
# -- employer type: string (nullable = true)
# -- marital: string (nullable = true)
#
# Out[31]: DataFrame[age: int, education: string, occupation: string, relationship: string, race: string, gender: string, capitalgain: int, capitalloss: int, income: string, age group: string, hr/wk: string, region: string, employer type: string, marital: string]</div>

# %%
census_clean = step3
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # Basic cleaning is done
# #Time for Some Visualizations and analyse my data

# %% [markdown]
# #KPI 2

# %%
#How to use groupby and aggregate functions alongwith it
#KPI2
daf02 = census_clean.groupby(['education']).agg({'capitalgain':'mean','capitalloss':'mean'})
display(daf02.sort("avg(capitalgain)", ascending  = False))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>education</th><th>avg(capitalloss)</th><th>avg(capitalgain)</th></tr></thead><tbody><tr><td>Prof-school</td><td>239.3936305732484</td><td>10981.208917197453</td></tr><tr><td>Doctorate</td><td>236.18566176470588</td><td>6068.02205882353</td></tr><tr><td>Masters</td><td>167.23070803500397</td><td>2567.1495624502786</td></tr><tr><td>Bachelors</td><td>124.98375165125495</td><td>1744.5273447820343</td></tr><tr><td>Preschool</td><td>47.09722222222222</td><td>843.8333333333334</td></tr><tr><td>Assoc-voc</td><td>69.66462480857581</td><td>805.1408882082695</td></tr><tr><td>HS-grad</td><td>69.4066833524995</td><td>581.5359534600555</td></tr><tr><td>Assoc-acdm</td><td>92.2733908427339</td><td>572.4452554744526</td></tr><tr><td>Some-college</td><td>73.83149813112436</td><td>570.4425699565612</td></tr><tr><td>5th-6th</td><td>68.86191536748329</td><td>387.0423162583519</td></tr><tr><td>9th</td><td>37.62278106508876</td><td>327.2869822485207</td></tr><tr><td>10th</td><td>59.37694194603434</td><td>323.71054783319704</td></tr><tr><td>7th-8th</td><td>57.410692588092346</td><td>252.37059538274605</td></tr><tr><td>11th</td><td>50.795552810376776</td><td>212.508956145769</td></tr><tr><td>12th</td><td>30.07625649913345</td><td>197.78336221837088</td></tr><tr><td>1st-4th</td><td>53.513513513513516</td><td>119.75225225225225</td></tr></tbody></table></div>

# %% [markdown]
# #KPI 3

# %%
#KPI3
daf03 = census_clean.groupBy(['income','age group']).agg({'capitalgain':'mean', 'capitalloss':'mean'})
display(daf03.sort("avg(capitalgain)", ascending = False))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>income</th><th>age group</th><th>avg(capitalloss)</th><th>avg(capitalgain)</th></tr></thead><tbody><tr><td>>50K</td><td>retired</td><td>217.38341346153845</td><td>6202.330528846154</td></tr><tr><td>>50K</td><td>senior</td><td>192.30252100840337</td><td>4451.461951447245</td></tr><tr><td>>50K</td><td>middle</td><td>191.16942841184138</td><td>3417.7482777881214</td></tr><tr><td>>50K</td><td>young</td><td>190.2149791955617</td><td>2985.9542302357836</td></tr><tr><td><=50K</td><td>retired</td><td>70.08077879038939</td><td>315.3384424192212</td></tr><tr><td><=50K</td><td>senior</td><td>64.9410719573586</td><td>170.50488599348535</td></tr><tr><td><=50K</td><td>middle</td><td>58.87821434275675</td><td>155.7339881808018</td></tr><tr><td><=50K</td><td>young</td><td>39.98693605972087</td><td>97.85491723466407</td></tr></tbody></table></div>

# %% [markdown]
# #KPI 4

# %%
#KPI 4
daf04 = census_clean.groupBy('race','income').agg({'income':'count'})
display(daf04.sort("count(income)", ascending = False))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>race</th><th>income</th><th>count(income)</th></tr></thead><tbody><tr><td>White</td><td><=50K</td><td>28696</td></tr><tr><td>White</td><td>>50K</td><td>10207</td></tr><tr><td>Black</td><td><=50K</td><td>3694</td></tr><tr><td>Asian-Pac-Islander</td><td><=50K</td><td>934</td></tr><tr><td>Black</td><td>>50K</td><td>534</td></tr><tr><td>Amer-Indian-Eskimo</td><td><=50K</td><td>382</td></tr><tr><td>Asian-Pac-Islander</td><td>>50K</td><td>369</td></tr><tr><td>Other</td><td><=50K</td><td>308</td></tr><tr><td>Amer-Indian-Eskimo</td><td>>50K</td><td>53</td></tr><tr><td>Other</td><td>>50K</td><td>45</td></tr></tbody></table></div>

# %% [markdown]
# #KPI stat

# %%
census_clean.groupBy('income').agg({'age':'mean'}).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+------------------+
# income|          avg(age)|
# +------+------------------+
#  &lt;=50K|36.749426706650205|
#   &gt;50K| 44.00606709493219|
# +------+------------------+
#
# </div>

# %% [markdown]
# #KPI 5

# %%
#KPI 5
daf05 = census_clean.groupBy(['gender','relationship']).agg({'age':'mean'})
#daf05.describe
display(daf05.sort("avg(age)", ascending = False))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>gender</th><th>relationship</th><th>avg(age)</th></tr></thead><tbody><tr><td>Male</td><td>Husband</td><td>43.35788909724082</td></tr><tr><td>Female</td><td>Unmarried</td><td>40.79030933479332</td></tr><tr><td>Female</td><td>Wife</td><td>39.97464114832536</td></tr><tr><td>Female</td><td>Not-in-family</td><td>39.738913525498894</td></tr><tr><td>Male</td><td>Unmarried</td><td>38.70044052863436</td></tr><tr><td>Female</td><td>Other-relative</td><td>36.90327868852459</td></tr><tr><td>Male</td><td>Not-in-family</td><td>36.58139904610493</td></tr><tr><td>Female</td><td>Husband</td><td>34.0</td></tr><tr><td>Male</td><td>Other-relative</td><td>30.687415426251693</td></tr><tr><td>Male</td><td>Wife</td><td>29.0</td></tr><tr><td>Male</td><td>Own-child</td><td>25.35028401406546</td></tr><tr><td>Female</td><td>Own-child</td><td>25.034141345169</td></tr></tbody></table></div>

# %% [markdown]
# #KPI
ascending = False))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age group</th><th>hr/wk</th><th>count(income)</th></tr></thead><tbody><tr><td>middle</td><td>Full time</td><td>12192</td></tr><tr><td>young</td><td>Full time</td><td>8519</td></tr><tr><td>senior</td><td>Full time</td><td>7506</td></tr><tr><td>middle</td><td>Overtime</td><td>4937</td></tr><tr><td>senior</td><td>Overtime</td><td>2998</td></tr><tr><td>young</td><td>Temp</td><td>2700</td></tr><tr><td>retired</td><td>Full time</td><td>1875</td></tr><tr><td>young</td><td>Overtime</td><td>1826</td></tr><tr><td>retired</td><td>Temp</td><td>859</td></tr><tr><td>middle</td><td>Temp</td><td>764</td></tr><tr><td>senior</td><td>Temp</td><td>534</td></tr><tr><td>retired</td><td>Overtime</td><td>512</td></tr></tbody></table></div>

# %% [markdown]
# #KPI 9

# %%
#KPI 9
daf09 = census_clean.groupBy(['employer type','income']).agg({'income':'count'})
display(daf09.sort("count(income)", ascending = False))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>employer type</th><th>income</th><th>count(income)</th></tr></thead><tbody><tr><td>Private</td><td><=50K</td><td>26056</td></tr><tr><td>Private</td><td>>50K</td><td>7251</td></tr><tr><td>Govt</td><td><=50K</td><td>3611</td></tr><tr><td>self_emp</td><td><=50K</td><td>3471</td></tr><tr><td>self_emp</td><td>>50K</td><td>1971</td></tr><tr><td>Govt</td><td>>50K</td><td>1435</td></tr><tr><td>Federal-gov</td><td><=50K</td><td>857</td></tr><tr><td>Federal-gov</td><td>>50K</td><td>549</td></tr><tr><td>Unemployed</td><td><=50K</td><td>19</td></tr><tr><td>Unemployed</td><td>>50K</td><td>2</td></tr></tbody></table></div>

# %% [markdown]
# #KPI 10

# %%
#KPI 10
display(census_clean.groupBy(['gender','employer type']).agg({'gender':'count'}))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>gender</th><th>employer type</th><th>count(gender)</th></tr></thead><tbody><tr><td>Male</td><td>self_emp</td><td>4626</td></tr><tr><td>Male</td><td>Govt</td><td>3047</td></tr><tr><td>Male</td><td>Unemployed</td><td>14</td></tr><tr><td>Male</td><td>Federal-gov</td><td>961</td></tr><tr><td>Female</td><td>Federal-gov</td><td>445</td></tr><tr><td>Female</td><td>Govt</td><td>1999</td></tr><tr><td>Male</td><td>Private</td><td>21879</td></tr><tr><td>Female</td><td>Unemployed</td><td>7</td></tr><tr><td>Female</td><td>self_emp</td><td>816</td></tr><tr><td>Female</td><td>Private</td><td>11428</td></tr></tbody></table></div>

# %% [markdown]
# #KPI 11

# %%
#KPI 11
daf11 = census_clean.groupBy(['employer type','hr/wk']).agg({'hr/wk':'count'})
display(daf11.sort('count(hr/wk)',ascending = False))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>employer type</th><th>hr/wk</th><th>count(hr/wk)</th></tr></thead><tbody><tr><td>Private</td><td>Full time</td><td>22963</td></tr><tr><td>Private</td><td>Overtime</td><td>6669</td></tr><tr><td>Private</td><td>Temp</td><td>3675</td></tr><tr><td>Govt</td><td>Full time</td><td>3607</td></tr><tr><td>self_emp</td><td>Overtime</td><td>2449</td></tr><tr><td>self_emp</td><td>Full time</td><td>2403</td></tr><tr><td>Federal-gov</td><td>Full time</td><td>1112</td></tr><tr><td>Govt</td><td>Overtime</td><td>921</td></tr><tr><td>self_emp</td><td>Temp</td><td>590</td></tr><tr><td>Govt</td><td>Temp</td><td>518</td></tr><tr><td>Federal-gov</td><td>Overtime</td><td>229</td></tr><tr><td>Federal-gov</td><td>Temp</td><td>65</td></tr><tr><td>Unemployed</td><td>Temp</td><td>9</td></tr><tr><td>Unemployed</td><td>Full time</td><td>7</td></tr><tr><td>Unemployed</td><td>Overtime</td><td>5</td></tr></tbody></table></div>

# %% [markdown]
# #KPI 12

# %%
#KPI 12
display(census_clean.groupBy(['gender','income']).agg({'income':'count'}))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>gender</th><th>income</th><th>count(income)</th></tr></thead><tbody><tr><td>Male</td><td><=50K</td><td>20988</td></tr><tr><td>Male</td><td>>50K</td><td>9539</td></tr><tr><td>Female</td><td><=50K</td><td>13026</td></tr><tr><td>Female</td><td>>50K</td><td>1669</td></tr></tbody></table></div>

# %% [markdown]
# #KPI 13

# %%
#KPI 13
daf13 = census_clean.groupBy(['marital','income']).agg({'income':'count'})
display(daf13.sort("count(income)", ascending  = False))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>marital</th><th>income</th><th>count(income)</th></tr></thead><tbody><tr><td>Never-married</td><td><=50K</td><td>13897</td></tr><tr><td>Married</td><td><=50K</td><td>12007</td></tr><tr><td>Married</td><td>>50K</td><td>9632</td></tr><tr><td>Not-Married</td><td><=50K</td><td>8110</td></tr><tr><td>Not-Married</td><td>>50K</td><td>875</td></tr><tr><td>Never-married</td><td>>50K</td><td>701</td></tr></tbody></table></div>

# %% [markdown]
# #KPI 14

# %%
#KPI 14
display(census_clean.groupBy(['marital','gender']).agg({'income':'count'}))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>marital</th><th>gender</th><th>count(income)</th></tr></thead><tbody><tr><td>Never-married</td><td>Male</td><td>8085</td></tr><tr><td>Married</td><td>Female</td><td>2508</td></tr><tr><td>Never-married</td><td>Female</td><td>6513</td></tr><tr><td>Not-Married</td><td>Female</td><td>5674</td></tr><tr><td>Not-Married</td><td>Male</td><td>3311</td></tr><tr><td>Married</td><td>Male</td><td>19131</td></tr></tbody></table></div>

# %% [markdown]
# #KPI 15

# %%
#KPI 15
daf15 = census_clean.groupBy(['marital','employer type']).agg({'income':'count'})
display(daf15.sort("count(income)", ascending = False))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>marital</th><th>employer type</th><th>count(income)</th></tr></thead><tbody><tr><td>Married</td><td>Private</td><td>14654</td></tr><tr><td>Never-married</td><td>Private</td><td>12011</td></tr><tr><td>Not-Married</td><td>Private</td><td>6642</td></tr><tr><td>Married</td><td>self_emp</td><td>3799</td></tr><tr><td>Married</td><td>Govt</td><td>2447</td></tr><tr><td>Never-married</td><td>Govt</td><td>1417</td></tr><tr><td>Not-Married</td><td>Govt</td><td>1182</td></tr><tr><td>Not-Married</td><td>self_emp</td><td>839</td></tr><tr><td>Never-married</td><td>self_emp</td><td>804</td></tr><tr><td>Married</td><td>Federal-gov</td><td>725</td></tr><tr><td>Never-married</td><td>Federal-gov</td><td>360</td></tr><tr><td>Not-Married</td><td>Federal-gov</td><td>321</td></tr><tr><td>Married</td><td>Unemployed</td><td>14</td></tr><tr><td>Never-married</td><td>Unemployed</td><td>6</td></tr><tr><td>Not-Married</td><td>Unemployed</td><td>1</td></tr></tbody></table></div>

# %% [markdown]
# #KPI 16

# %%
#KPI 16
#display(census_clean.groupBy(['education','income']).agg({'income':'count'}))
daf16 = census_clean.groupBy(['education','income']).agg({'income':'count'})
display(  daf16.sort("count(income)", ascending=False))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
#39;, race=&#39;White&#39;, gender=&#39;Male&#39;, capitalgain=0, capitalloss=0, income=&#39;&lt;=50K&#39;, age group=&#39;young&#39;, hr/wk=&#39;Temp&#39;, region=&#39;North America&#39;, employer type=&#39;Govt&#39;, marital=&#39;Never-married&#39;),
#  Row(age=43, education=&#39;HS-grad&#39;, occupation=&#39;Adm-clerical&#39;, relationship=&#39;Wife&#39;, race=&#39;White&#39;, gender=&#39;Female&#39;, capitalgain=0, capitalloss=0, income=&#39;&lt;=50K&#39;, age group=&#39;middle&#39;, hr/wk=&#39;Full time&#39;, region=&#39;North America&#39;, employer type=&#39;Private&#39;, marital=&#39;Married&#39;),
#  Row(age=37, education=&#39;HS-grad&#39;, occupation=&#39;Machine-op-inspct&#39;, relationship=&#39;Unmarried&#39;, race=&#39;White&#39;, gender=&#39;Female&#39;, capitalgain=0, capitalloss=0, income=&#39;&lt;=50K&#39;, age group=&#39;middle&#39;, hr/wk=&#39;Temp&#39;, region=&#39;North America&#39;, employer type=&#39;Private&#39;, marital=&#39;Not-Married&#39;),
#  Row(age=34, education=&#39;Bachelors&#39;, occupation=&#39;Tech-support&#39;, relationship=&#39;Husband&#39;, race=&#39;White&#39;, gender=&#39;Male&#39;, capitalgain=0, capitalloss=0, income=&#39;&gt;50K&#39;, age group=&#39;middle&#39;, hr/wk=&#39;Overtime&#39;, region=&#39;North America&#39;, employer type=&#39;Private&#39;, marital=&#39;Married&#39;),
#  Row(age=34, education=&#39;Some-college&#39;, occupation=&#39;Other-service&#39;, relationship=&#39;Own-child&#39;, race=&#39;Black&#39;, gender=&#39;Female&#39;, capitalgain=0, capitalloss=0, income=&#39;&lt;=50K&#39;, age group=&#39;middle&#39;, hr/wk=&#39;Full time&#39;, region=&#39;North America&#39;, employer type=&#39;Private&#39;, marital=&#39;Never-married&#39;),
#  Row(age=25, education=&#39;Bachelors&#39;, occupation=&#39;Prof-specialty&#39;, relationship=&#39;Not-in-family&#39;, race=&#39;White&#39;, gender=&#39;Male&#39;, capitalgain=0, capitalloss=0, income=&#39;&lt;=50K&#39;, age group=&#39;young&#39;, hr/wk=&#39;Full time&#39;, region=&#39;Latin &amp; South America&#39;, employer type=&#39;Private&#39;, marital=&#39;Never-married&#39;),
#  Row(age=25, education=&#39;Bachelors&#39;, occupation=&#39;Prof-specialty&#39;, relationship=&#39;Husband&#39;, race=&#39;White&#39;, gender=&#39;Male&#39;, capitalgain=0, capitalloss=0, income=&#39;&lt;=50K&#39;, age group=&#39;young&#39;, hr/wk=&#39;Full time&#39;, region=&#39;North America&#39;, employer type=&#39;Private&#39;, marital=&#39;Married&#39;),
#  Row(age=45, education=&#39;HS-grad&#39;, occupation=&#39;Craft-repair&#39;, relationship=&#39;Husband&#39;, race=&#39;White&#39;, gender=&#39;Male&#39;, capitalgain=7298, capitalloss=0, income=&#39;&gt;50K&#39;, age group=&#39;senior&#39;, hr/wk=&#39;Overtime&#39;, region=&#39;North America&#39;, employer type=&#39;self_emp&#39;, mari

# %%
#to view all the string labels in my dataframe
#dtype = [ stype for col,stype in census_clean.dtypes]
for col,dtype in census_clean.dtypes:
  if dtype=='string':
    print(col)
    census_clean.select(col).distinct().show()
    print("----------------------------------------")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">education
# +------------+
#    education|
# +------------+
#         10th|
#      Masters|
#      5th-6th|
#   Assoc-acdm|
#    Assoc-voc|
#      7th-8th|
#          9th|
#      HS-grad|
#    Bachelors|
#         11th|
#      1st-4th|
#    Preschool|
#         12th|
#    Doctorate|
# Some-college|
#  Prof-school|
# +------------+
#
# ----------------------------------------
# occupation
# +-----------------+
#        occupation|
# +-----------------+
#             Sales|
#   Exec-managerial|
#    Prof-specialty|
# Handlers-cleaners|
#   Farming-fishing|
#      Craft-repair|
#  Transport-moving|
#   Priv-house-serv|
#   Protective-serv|
#     Other-service|
#      Tech-support|
# Machine-op-inspct|
#      Armed-Forces|
#      Adm-clerical|
# +-----------------+
#
# ----------------------------------------
# relationship
# +--------------+
#   relationship|
# +--------------+
#      Own-child|
#  Not-in-family|
#      Unmarried|
#           Wife|
# Other-relative|
#        Husband|
# +--------------+
#
# ----------------------------------------
# race
# +------------------+
#               race|
# +------------------+
#              Other|
# Amer-Indian-Eskimo|
#              White|
# Asian-Pac-Islander|
#              Black|
# +------------------+
#
# ----------------------------------------
# gender
# +------+
# gender|
# +------+
# Female|
#   Male|
# +------+
#
# ----------------------------------------
# income
# +------+
# income|
# +------+
#  &lt;=50K|
#   &gt;50K|
# +------+
#
# ----------------------------------------
# age group
# +---------+
# age group|
# +---------+
#   retired|
#    senior|
#     young|
#    middle|
# +---------+
#
# ----------------------------------------
# hr/wk
# +---------+
#     hr/wk|
# +---------+
#      Temp|
# Full time|
#  Overtime|
# +---------+
#
# ----------------------------------------
# region
# +--------------------+
#               region|
# +--------------------+
#               Europe|
# Latin &amp; South Ame...|
#        North America|
#               Others|
#                 Asia|
# +--------------------+
#
# ----------------------------------------
# employer type
# +-------------+
# employer type|
# +-------------+
#          Govt|
#      self_emp|
#       Private|
#   Federal-gov|
#    Unemployed|
# +-------------+
#
# ----------------------------------------
# marital
# +-------------+
#       marital|
# +-------------+
#       Married|
# Never-married|
#   Not-Married|
# +-------------+
#
# ----------------------------------------
# </div>

# %%
from pyspark.ml.feature import StringIndexer, OneHotEncoder, VectorAssembler
from pyspark.ml import Pipeline
categorical_column = [col for col,dtype  in census_clean.dtypes if dtype=='string']
#column = [col for col,dtype  in census_clean.dtypes if dtype=='string']
#String_index = [StringIndexer(inputCol=col, outputCol='index_'+col) for col,dtype  in census_clean.dtypes if dtype=='string'and col!='income']
String_index = [StringIndexer(inputCol=col, outputCol='index_'+col) for col  in categorical_column if col!='income']
String_index += [StringIndexer(inputCol='income', outputCol='label')]
print(String_index)
sample_viz = Pipeline(stages=String_index).fit(census_clean).transform(census_clean)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[StringIndexer_65d2dcadb678, StringIndexer_29851f8a9ffa, StringIndexer_57403f823872, StringIndexer_3dc62df146ff, StringIndexer_d805780be55d, StringIndexer_cdaedcd66fd0, StringIndexer_7bcafd35766f, StringIndexer_71f75003179a, StringIndexer_11b30d948449, StringIndexer_7dd9f96b1154, StringIndexer_0a073f18a6cc]
# </div>

# %%
column = [col for col,dtype  in census_clean.dtypes if dtype=='string' or col in ['age', 'income','capitalgain','capitalloss']]
sample_viz = sample_viz.drop(*column)
sample_viz.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- index_education: double (nullable = false)
# -- index_occupation: double (nullable = false)
# -- index_relationship: double (nullable = false)
# -- index_race: double (nullable = false)
# -- index_gender: double (nullable = false)
# -- index_age group: double (nullable = false)
# -- index_hr/wk: double (nullable = false)
# -- index_region: double (nullable = false)
# -- index_employer type: double (nullable = false)
# -- index_marital: double (nullable = false)
# -- label: double (nullable = false)
#
# </div>

# %%
from pyspark.mllib.stat import Statistics
import pandas as pd

# df = sqlCtx.read.format('com.databricks.spark.csv').option('header', 'true').option('inferschema', 'true').load('corr_test.csv')
df = sample_viz
col_names = df.columns
features = df.rdd.map(lambda row: row[0:])
corr_mat=Statistics.corr(features, method="spearman",)
corr_df = pd.DataFrame(corr_mat.round(4))
corr_df.index, corr_df.columns = col_names, col_names
corr_df = corr_df.reset_index()
display(corr_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>